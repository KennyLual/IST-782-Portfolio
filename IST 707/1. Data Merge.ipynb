# %% [markdown]
# ### Merging Meteorological Data (90 Stations)

# %%
# Here we will merge all meteorological data into a one file and also change the structure of the data into a right format so we can analyze further
# Please unzip all meteorological data and load them directly next to this code
# Load relevant libaries and data
import pandas as pd
import glob
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os

# List of region names corresponding to the CSV files
stations = ["burlington", "columbus junct 2 ssw", "fairfield", "iowa - southeast climate division", "keosauqua", "burlingtonairport", "donnellson", "fortmadison", "keokuk", "mount-pleasant", 
           "allerton", "centerville", "chariton", "des moines area", "iowa - south central climate division", "iowa drought region 5 - southeast", "newton", "osceola-3-wsw", "oskaloosa", "rathbun dam",
           "atlantic-1-ne", "clarinda", "corning", "creston", "greenfield", "iowa - southwest climate division", "iowa drought region 4 - southwest", "oakland-2-e", "shenandoah-1-ne", "winterset",
           "iowadroughtregion1", "iowanorthwestclimate", "lemars", "primghar", "rockrapids", "sibley5", "siouxcenter", "spencer", "siouxrapids", "spencerarea",
           "algona", "estherville4e", "esthervillemunicipal", "fortdodge", "iowadroughtregion2", "jefferson", "pocahontas", "saccity", "emmetsburg", "webstercity",
           "audubon", "battle creek 3ne", "carroll-2-ssw", "denison", "ida grove area", "iowa - west central climate division", "little sioux 2nw", "mapleton no. 2", "sac-city", "sioux city area",
           "elkader6ssw", "fayette", "iowadroughtregion3", "iowanortheastclimatedivision", "newhampton", "oelwein1e", "oelweinarea", "postville", "stanley", "waukon",
           "ames 5 se", "ames area", "ames municipal ap", "ames-8-wsw", "boone", "grinnell-3-sw", "grundy-center", "iowa average", "marshalltown municipal ap", "toledo",
           "anamosa3ssw", "cascade", "cedarrapids1", "cedarrapidsarea", "clinton1", "dubuquearea", "iowaeastcentral", "lowden", "manchester2", "maquioketa2w"] 
#Southeast, SouthCentral,Southwest, Northwest, Northcentral,  Westcentral, Northeast, Central, eastcentral

# Iterate through each region
for region in stations:
    try:
        # Load the CSV for the current region (no header in the file)
        df = pd.read_csv(f'{region}.csv', header=None)
        
        # Add 'Region' column with the region name for this dataset
        df['Stations'] = region
        
        # Add proper column names: ['Type', 'Year', 'Jan', 'Feb', ..., 'Dec', 'Region']
        columns = ['Type', 'Year'] + [f'Month_{i}' for i in range(1, 13)] + ['Stations']
        df.columns = columns
        
        # Melt the DataFrame to transform the data structure as required
        df_melted = df.melt(id_vars=["Type", "Year", "Stations"], var_name="Month", value_name="Value")
        
        # Pivot the melted DataFrame to get 'prec', 'tmin', and 'tmax' as columns and each month as rows
        df_pivoted = df_melted.pivot_table(index=["Year", "Month", "Stations"], columns="Type", values="Value").reset_index()
        
        # Sort the DataFrame by Year and Month to get the desired order of rows from Month_1 of each year to Month_12 of each year
        df_pivoted = df_pivoted.sort_values(by=["Year", "Month"])
        
        # Save the modified dataframe back to a CSV (overwrite the original file or save with a new name)
        df_pivoted.to_csv(f'{region}_modified.csv', index=False)
        
        # Log the success
        print(f"Successfully modified data for region: {region}")
        print(df_pivoted.head())  # Show the first 5 rows of the modified file
        
    except FileNotFoundError:
        print(f"File for region {region} not found.")
    except Exception as e:
        print(f"An error occurred for region {region}: {e}")
# Out:
# Successfully modified data for region: burlington
# Type  Year     Month    Stations    prec   tmax   tmin
# 0     2015   Month_1  burlington   30.48   0.43  -9.37
# 1     2015  Month_10  burlington   56.14  19.02   6.70
# 2     2015  Month_11  burlington  157.48  12.78   2.02
# 3     2015  Month_12  burlington  123.71   7.67  -0.20
# 4     2015   Month_2  burlington   39.12  -3.00 -13.67
# Successfully modified data for region: columbus junct 2 ssw
# Type  Year     Month              Stations    prec   tmax   tmin
# 0     2015   Month_1  columbus junct 2 ssw   22.35  -0.66 -10.32
# 1     2015  Month_10  columbus junct 2 ssw   52.07  18.39   6.11
# 2     2015  Month_11  columbus junct 2 ssw  123.19  11.98   1.06
# 3     2015  Month_12  columbus junct 2 ssw  117.61   6.83  -0.91
# 4     2015   Month_2  columbus junct 2 ssw   37.09  -3.58 -14.28
# Successfully modified data for region: fairfield
# Type  Year     Month   Stations    prec   tmax   tmin
# 0     2015   Month_1  fairfield   22.36  -0.07 -10.50
# 1     2015  Month_10  fairfield   40.39  18.11   6.11
# 2     2015  Month_11  fairfield  143.26  12.31   2.41
# 3     2015  Month_12  fairfield  117.88   7.35  -0.22
# 4     2015   Month_2  fairfield   43.44  -3.41 -14.05
# Successfully modified data for region: iowa - southeast climate division
# Type  Year     Month                           Stations    prec   tmax   tmin
# 0     2015   Month_1  iowa - southeast climate division   20.07   0.90 -10.32
# 1     2015  Month_10  iowa - southeast climate division   51.82  19.41   5.66
# 2     2015  Month_11  iowa - southeast climate division  126.49  13.11   0.98
# 3     2015  Month_12  iowa - southeast climate division  122.17   7.74  -1.11
# 4     2015   Month_2  iowa - southeast climate division   38.61  -2.50 -14.68
# Successfully modified data for region: keosauqua
# Type  Year     Month   Stations    prec   tmax   tmin
# 0     2015   Month_1  keosauqua    3.82   0.68 -11.59
# 1     2015  Month_10  keosauqua   54.10  19.39   6.31
# 2     2015  Month_11  keosauqua  113.04  14.37   1.31
# 3     2015  Month_12  keosauqua   69.86   7.94  -1.40
# 4     2015   Month_2  keosauqua   63.51  -2.50 -14.15
# Successfully modified data for region: burlingtonairport
# Type  Year     Month           Stations    prec   tmax   tmin
# 0     2015   Month_1  burlingtonairport   39.12   0.93  -8.67
# 1     2015  Month_10  burlingtonairport   52.59  19.03   7.37
# 2     2015  Month_11  burlingtonairport  151.89  12.54   2.39
# 3     2015  Month_12  burlingtonairport  114.56   7.50   0.50
# 4     2015   Month_2  burlingtonairport   22.36  -3.04 -13.49
# Successfully modified data for region: donnellson
# Type  Year     Month    Stations    prec   tmax   tmin
# 0     2015   Month_1  donnellson   25.92   0.75  -9.77
# 1     2015  Month_10  donnellson   54.36  19.77   6.57
# 2     2015  Month_11  donnellson  131.32  13.16   2.59
# 3     2015  Month_12  donnellson  137.42   7.89  -0.22
# 4     2015   Month_2  donnellson   43.69  -2.12 -13.57
# Successfully modified data for region: fortmadison
# Type  Year     Month     Stations    prec   tmax   tmin
# 0     2015   Month_1  fortmadison   29.98   0.75  -8.78
# 1     2015  Month_10  fortmadison   50.04  18.47   8.33
# 2     2015  Month_11  fortmadison  129.80  12.24   2.56
# 3     2015  Month_12  fortmadison   98.04   7.35   0.36
# 4     2015   Month_2  fortmadison   31.50  -3.08 -13.10
# Successfully modified data for region: keokuk
# Type  Year     Month Stations    prec   tmax   tmin
# 0     2015   Month_1   keokuk   21.84   0.61  -8.24
# 1     2015  Month_10   keokuk   48.26  18.79   7.82
# 2     2015  Month_11   keokuk  159.51  13.15   2.72
# 3     2015  Month_12   keokuk  114.81   8.58   0.33
# 4     2015   Month_2   keokuk   48.77  -1.41 -12.58
# Successfully modified data for region: mount-pleasant
# Type  Year     Month        Stations    prec   tmax   tmin
# 0     2015   Month_1  mount-pleasant   24.13  -0.02 -11.06
# 1     2015  Month_10  mount-pleasant   52.07  18.31   5.15
# 2     2015  Month_11  mount-pleasant  120.65  12.52   0.72
# 3     2015  Month_12  mount-pleasant  119.38   7.08  -0.99
# 4     2015   Month_2  mount-pleasant   25.40  -2.80 -14.61
# Successfully modified data for region: allerton
# Type  Year     Month  Stations    prec   tmax   tmin
# 0     2015   Month_1  allerton    5.09   1.72 -10.43
# 1     2015  Month_10  allerton   42.94  19.21   6.37
# 2     2015  Month_11  allerton  148.85  12.32   1.43
# 3     2015  Month_12  allerton  143.53   6.09  -1.99
# 4     2015   Month_2  allerton   42.17  -2.57 -14.67
# Successfully modified data for region: centerville
# Type  Year     Month     Stations    prec   tmax   tmin
# 0     2015   Month_1  centerville   11.18   1.25 -10.92
# 1     2015  Month_10  centerville   40.13  18.96   5.44
# 2     2015  Month_11  centerville  168.66  13.43   0.91
# 3     2015  Month_12  centerville  125.98   7.11  -1.95
# 4     2015   Month_2  centerville   35.05  -2.20 -14.40
# Successfully modified data for region: chariton
# Type  Year     Month  Stations    prec   tmax   tmin
# 0     2015   Month_1  chariton    2.54   1.41 -11.28
# 1     2015  Month_10  chariton   46.99  18.39   3.75
# 2     2015  Month_11  chariton  110.74  12.65  -0.13
# 3     2015  Month_12  chariton  160.02   6.20  -2.69
# 4     2015   Month_2  chariton   35.06  -3.10 -15.69
# Successfully modified data for region: des moines area
# Type  Year     Month         Stations    prec   tmax   tmin
# 0     2015   Month_1  des moines area   34.31   2.11  -8.35
# 1     2015  Month_10  des moines area   35.82  18.91   8.17
# 2     2015  Month_11  des moines area   85.35  12.69   2.54
# 3     2015  Month_12  des moines area  138.19   6.08  -1.42
# 4     2015   Month_2  des moines area   17.05  -2.70 -13.02
# Successfully modified data for region: iowa - south central climate division
# Type  Year     Month                               Stations    prec   tmax  \
# 0     2015   Month_1  iowa - south central climate division    9.14   1.67
# 1     2015  Month_10  iowa - south central climate division   37.34  19.29
# 2     2015  Month_11  iowa - south central climate division  115.82  13.00
# 3     2015  Month_12  iowa - south central climate division  131.32   6.45
# 4     2015   Month_2  iowa - south central climate division   40.13  -1.96
#
# Type   tmin
# 0    -10.79
# 1      5.94
# 2      1.19
# 3     -2.38
# 4    -14.64
# Successfully modified data for region: iowa drought region 5 - southeast
# Type  Year     Month                           Stations    prec   tmax   tmin
# 0     2015   Month_1  iowa drought region 5 - southeast   15.75   1.09 -10.56
# 1     2015  Month_10  iowa drought region 5 - southeast   48.51  19.02   5.56
# 2     2015  Month_11  iowa drought region 5 - southeast  115.82  12.69   0.80
# 3     2015  Month_12  iowa drought region 5 - southeast  129.79   6.83  -1.94
# 4     2015   Month_2  iowa drought region 5 - southeast   38.35  -2.74 -14.96
# Successfully modified data for region: newton
# Type  Year     Month Stations    prec   tmax   tmin
# 0     2015   Month_1   newton   12.71  -0.84 -10.54
# 1     2015  Month_10   newton   42.93  17.72   5.87
# 2     2015  Month_11   newton   71.38  11.06   0.56
# 3     2015  Month_12   newton  113.03   4.93  -2.26
# 4     2015   Month_2   newton   26.93  -4.98 -15.71
# Successfully modified data for region: osceola-3-wsw
# Type  Year     Month       Stations    prec   tmax   tmin
# 0     2015   Month_1  osceola-3-wsw    6.35   2.04 -11.86
# 1     2015  Month_10  osceola-3-wsw   37.08  19.77   4.50
# 2     2015  Month_11  osceola-3-wsw  101.86  12.96   0.35
# 3     2015  Month_12  osceola-3-wsw  106.43   5.65  -2.61
# 4     2015   Month_2  osceola-3-wsw   33.27  -2.06 -15.40
# Successfully modified data for region: oskaloosa
# Type  Year     Month   Stations    prec   tmax   tmin
# 0     2015   Month_1  oskaloosa   18.30   0.96 -10.92
# 1     2015  Month_10  oskaloosa   57.66  18.75   5.91
# 2     2015  Month_11  oskaloosa  132.08  11.92   1.26
# 3     2015  Month_12  oskaloosa  144.02   6.63  -1.34
# 4     2015   Month_2  oskaloosa   44.46  -2.18 -14.72
# Successfully modified data for region: rathbun dam
# Type  Year     Month     Stations    prec   tmax   tmin
# 0     2015   Month_1  rathbun dam   14.73   1.02 -10.94
# 1     2015  Month_10  rathbun dam   41.91  18.35   6.06
# 2     2015  Month_11  rathbun dam  142.24  12.65   0.67
# 3     2015  Month_12  rathbun dam  115.83   6.63  -2.11
# 4     2015   Month_2  rathbun dam   33.28  -1.73 -14.34
# Successfully modified data for region: atlantic-1-ne
# Type  Year     Month       Stations    prec   tmax   tmin
# 0     2015   Month_1  atlantic-1-ne    4.33   2.09 -11.15
# 1     2015  Month_10  atlantic-1-ne   32.26  19.28   4.35
# 2     2015  Month_11  atlantic-1-ne   90.68  11.94  -0.20
# 3     2015  Month_12  atlantic-1-ne  168.16   4.16  -4.91
# 4     2015   Month_2  atlantic-1-ne   23.38  -2.00 -15.19
# Successfully modified data for region: clarinda
# Type  Year     Month  Stations    prec   tmax   tmin
# 0     2015   Month_1  clarinda    3.56   3.37 -11.29
# 1     2015  Month_10  clarinda   29.72  19.59   5.91
# 2     2015  Month_11  clarinda   96.78  13.14   0.38
# 3     2015  Month_12  clarinda  156.47   5.66  -3.41
# 4     2015   Month_2  clarinda   34.55  -1.03 -13.63
# Successfully modified data for region: corning
# Type  Year     Month Stations    prec   tmax   tmin
# 0     2015   Month_1  corning    3.05   2.26 -11.04
# 1     2015  Month_10  corning   26.67  19.20   6.15
# 2     2015  Month_11  corning  101.35  12.46   1.24
# 3     2015  Month_12  corning  148.59   5.27  -3.37
# 4     2015   Month_2  corning   33.28  -1.15 -13.83
# Successfully modified data for region: creston
# Type  Year     Month Stations    prec   tmax   tmin
# 0     2015   Month_1  creston    7.37   1.92 -10.08
# 1     2015  Month_10  creston   13.72  18.56   6.20
# 2     2015  Month_11  creston  110.49  11.89   0.39
# 3     2015  Month_12  creston  171.96   4.76  -3.67
# 4     2015   Month_2  creston   46.23  -1.98 -15.28
# Successfully modified data for region: greenfield
# Type  Year     Month    Stations    prec   tmax   tmin
# 0     2015   Month_1  greenfield    7.88   1.26 -10.50
# 1     2015  Month_10  greenfield   40.39  18.83   6.29
# 2     2015  Month_11  greenfield  127.51  12.31   1.17
# 3     2015  Month_12  greenfield  159.52   5.20  -3.89
# 4     2015   Month_2  greenfield   34.80  -3.29 -14.55
# Successfully modified data for region: iowa - southwest climate division
# Type  Year     Month                           Stations    prec   tmax   tmin
# 0     2015   Month_1  iowa - southwest climate division    4.32   3.10 -10.65
# 1     2015  Month_10  iowa - southwest climate division   25.15  20.06   6.00
# 2     2015  Month_11  iowa - southwest climate division   89.92  13.17   0.80
# 3     2015  Month_12  iowa - southwest climate division  148.08   5.61  -3.82
# 4     2015   Month_2  iowa - southwest climate division   34.04  -1.17 -14.72
# Successfully modified data for region: iowa drought region 4 - southwest
# Type  Year     Month                           Stations    prec   tmax   tmin
# 0     2015   Month_1  iowa drought region 4 - southwest    4.57   2.56 -10.88
# 1     2015  Month_10  iowa drought region 4 - southwest   27.43  19.91   5.83
# 2     2015  Month_11  iowa drought region 4 - southwest   93.73  12.78   0.48
# 3     2015  Month_12  iowa drought region 4 - southwest  141.48   5.20  -4.07
# 4     2015   Month_2  iowa drought region 4 - southwest   32.51  -1.55 -14.96
# Successfully modified data for region: oakland-2-e
# Type  Year     Month     Stations    prec   tmax   tmin
# 0     2015   Month_1  oakland-2-e    2.30   2.20 -10.32
# 1     2015  Month_10  oakland-2-e   37.09  19.20   5.83
# 2     2015  Month_11  oakland-2-e   90.43  11.84   0.86
# 3     2015  Month_12  oakland-2-e  158.51   4.10  -4.32
# 4     2015   Month_2  oakland-2-e   28.96  -2.66 -14.03
# Successfully modified data for region: shenandoah-1-ne
# Type  Year     Month         Stations    prec   tmax   tmin
# 0     2015   Month_1  shenandoah-1-ne    4.33   3.56 -10.29
# 1     2015  Month_10  shenandoah-1-ne   18.29  20.61   6.85
# 2     2015  Month_11  shenandoah-1-ne  114.82  13.37   2.24
# 3     2015  Month_12  shenandoah-1-ne  157.23   5.81  -3.39
# 4     2015   Month_2  shenandoah-1-ne   29.47  -0.65 -12.90
# Successfully modified data for region: winterset
# Type  Year     Month   Stations    prec   tmax   tmin
# 0     2015   Month_1  winterset    4.08   1.08 -10.43
# 1     2015  Month_10  winterset   26.67  18.67   5.78
# 2     2015  Month_11  winterset   77.48  11.67   1.61
# 3     2015  Month_12  winterset  139.71   5.00  -3.28
# 4     2015   Month_2  winterset   33.28  -3.02 -14.50
# Successfully modified data for region: iowadroughtregion1
# Type  Year     Month            Stations    prec   tmax   tmin
# 0     2015   Month_1  iowadroughtregion1   11.68  -0.59 -12.15
# 1     2015  Month_10  iowadroughtregion1   37.85  19.09   4.33
# 2     2015  Month_11  iowadroughtregion1  108.20  10.15  -1.72
# 3     2015  Month_12  iowadroughtregion1   79.76   2.13  -6.13
# 4     2015   Month_2  iowadroughtregion1   19.05  -3.17 -15.81
# Successfully modified data for region: iowanorthwestclimate
# Type  Year     Month              Stations    prec   tmax   tmin
# 0     2015   Month_1  iowanorthwestclimate   13.46  -1.51 -12.44
# 1     2015  Month_10  iowanorthwestclimate   44.20  18.55   3.84
# 2     2015  Month_11  iowanorthwestclimate  111.76   9.37  -1.95
# 3     2015  Month_12  iowanorthwestclimate   79.25   1.72  -6.36
# 4     2015   Month_2  iowanorthwestclimate   18.54  -4.11 -16.35
# Successfully modified data for region: lemars
# Type  Year     Month Stations    prec   tmax   tmin
# 0     2015   Month_1   lemars   21.59  -1.44 -12.13
# 1     2015  Month_10   lemars   39.62  19.11   5.19
# 2     2015  Month_11   lemars  105.16   9.54  -1.78
# 3     2015  Month_12   lemars   84.08   2.07  -5.98
# 4     2015   Month_2   lemars   34.29  -2.61 -15.08
# Successfully modified data for region: primghar
# Type  Year     Month  Stations    prec   tmax   tmin
# 0     2015   Month_1  primghar   14.22  -1.61 -10.81
# 1     2015  Month_10  primghar   48.01  19.01   6.79
# 2     2015  Month_11  primghar  149.10   9.62   0.27
# 3     2015  Month_12  primghar   61.47   1.63  -4.71
# 4     2015   Month_2  primghar   15.75  -2.72 -14.40
# Successfully modified data for region: rockrapids
# Type  Year     Month    Stations    prec   tmax   tmin
# 0     2015   Month_1
# Type  Year     Month Stations    prec   tmax   tmin
# 0     2015   Month_1  denison    9.66   0.02 -10.06
# 1     2015  Month_10  denison   42.67  17.76   5.65
# 2     2015  Month_11  denison  145.80   9.85  -0.20
# 3     2015  Month_12  denison  181.61   1.92  -4.91
# 4     2015   Month_2  denison   29.73  -3.65 -14.33
# Successfully modified data for region: ida grove area
# Type  Year     Month        Stations    prec   tmax   tmin
# 0     2015   Month_1  ida grove area    5.46  -0.75 -12.63
# 1     2015  Month_10  ida grove area   30.99  18.72   3.70
# 2     2015  Month_11  ida grove area   93.99  10.75  -1.42
# 3     2015  Month_12  ida grove area  120.15   2.24  -6.20
# 4     2015   Month_2  ida grove area   12.37  -3.89 -15.99
# Successfully modified data for region: iowa - west central climate division
# Type  Year     Month                              Stations    prec   tmax  \
# 0     2015   Month_1  iowa - west central climate division    7.62   0.86
# 1     2015  Month_10  iowa - west central climate division   33.53  19.27
# 2     2015  Month_11  iowa - west central climate division   97.54  11.48
# 3     2015  Month_12  iowa - west central climate division  132.59   3.85
# 4     2015   Month_2  iowa - west central climate division   26.42  -2.84
#
# Type   tmin
# 0    -11.54
# 1      4.93
# 2     -0.56
# 3     -4.89
# 4    -15.77
# Successfully modified data for region: little sioux 2nw
# Type  Year     Month          Stations    prec   tmax   tmin
# 0     2015   Month_1  little sioux 2nw    8.39   1.18 -12.20
# 1     2015  Month_10  little sioux 2nw   46.23  19.34   5.04
# 2     2015  Month_11  little sioux 2nw   88.14  11.46  -1.15
# 3     2015  Month_12  little sioux 2nw  148.09   3.15  -5.39
# 4     2015   Month_2  little sioux 2nw   34.31  -2.30 -15.67
# Successfully modified data for region: mapleton no. 2
# Type  Year     Month        Stations    prec   tmax   tmin
# 0     2015   Month_1  mapleton no. 2    8.14  -0.37 -11.63
# 1     2015  Month_10  mapleton no. 2   28.96  18.43   4.61
# 2     2015  Month_11  mapleton no. 2  104.39  10.50  -0.74
# 3     2015  Month_12  mapleton no. 2  111.51   2.74  -5.11
# 4     2015   Month_2  mapleton no. 2   24.40  -3.10 -15.26
# Successfully modified data for region: sac-city
# Type  Year     Month  Stations    prec   tmax   tmin
# 0     2015   Month_1  sac-city    7.12  -1.40 -12.01
# 1     2015  Month_10  sac-city   54.87  17.81   4.46
# 2     2015  Month_11  sac-city  129.03   9.41  -0.65
# 3     2015  Month_12  sac-city  132.60   1.90  -5.63
# 4     2015   Month_2  sac-city   21.60  -4.86 -15.70
# Successfully modified data for region: sioux city area
# Type  Year     Month         Stations    prec   tmax   tmin
# 0     2015   Month_1  sioux city area   16.28   1.61 -10.30
# 1     2015  Month_10  sioux city area   21.85  19.57   5.34
# 2     2015  Month_11  sioux city area  115.58  11.07  -0.67
# 3     2015  Month_12  sioux city area   72.65   3.44  -4.85
# 4     2015   Month_2  sioux city area    8.15  -1.03 -13.47
# Successfully modified data for region: elkader6ssw
# Type  Year     Month     Stations    prec   tmax   tmin
# 0     2015   Month_1  elkader6ssw   18.30  -3.17 -14.25
# 1     2015  Month_10  elkader6ssw   66.30  16.86   2.76
# 2     2015  Month_11  elkader6ssw  109.47   9.96  -1.61
# 3     2015  Month_12  elkader6ssw  139.21   4.52  -2.92
# 4     2015   Month_2  elkader6ssw   22.37  -6.87 -21.35
# Successfully modified data for region: fayette
# Type  Year     Month Stations    prec   tmax   tmin
# 0     2015   Month_1
# Type  Year     Month   Stations    prec   tmax   tmin
# 0     2015   Month_1  ames 5 se   17.04  -0.79 -11.54
# 1     2015  Month_10  ames 5 se   47.76  17.81   5.20
# 2     2015  Month_11  ames 5 se   75.44  10.69   0.24
# 3     2015  Month_12  ames 5 se  163.34   4.21  -3.26
# 4     2015   Month_2  ames 5 se   27.20  -4.84 -15.89
# Successfully modified data for region: ames area
# Type  Year     Month   Stations    prec   tmax   tmin
# 0     2015   Month_1  ames area   17.20  -0.79 -11.54
# 1     2015  Month_10  ames area   47.76  17.81   5.20
# 2     2015  Month_11  ames area   75.44  10.69   0.24
# 3     2015  Month_12  ames area  163.34   4.21  -3.26
# 4     2015   Month_2  ames area   27.41  -4.84 -15.89
# Successfully modified data for region: ames municipal ap
# Type  Year     Month           Stations    prec   tmax   tmin
# 0     2015   Month_1  ames municipal ap   28.97   0.29 -10.68
# 1     2015  Month_10  ames municipal ap   46.74  17.90   5.47
# 2     2015  Month_11  ames municipal ap   68.33  11.04   0.13
# 3     2015  Month_12  ames municipal ap  126.01   4.48  -2.96
# 4     2015   Month_2  ames municipal ap    6.11  -4.72 -16.09
# Successfully modified data for region: ames-8-wsw
# Type  Year     Month    Stations    prec   tmax   tmin
# 0     2015   Month_1  ames-8-wsw    4.83   1.19  -9.76
# 1     2015  Month_10  ames-8-wsw   32.26  18.57   6.06
# 2     2015  Month_11  ames-8-wsw   69.85  11.19   0.69
# 3     2015  Month_12  ames-8-wsw  128.28   3.80  -3.03
# 4     2015   Month_2  ames-8-wsw   23.88  -3.77 -14.90
# Successfully modified data for region: boone
# Type  Year     Month Stations    prec   tmax   tmin
# 0     2015   Month_1    boone   16.27  -0.39 -11.72
# 1     2015  Month_10    boone   37.09  18.12   4.96
# 2     2015  Month_11    boone   97.28  10.85   0.07
# 3     2015  Month_12    boone  155.98   3.87  -4.01
# 4     2015   Month_2    boone   38.38  -4.37 -16.09
# Successfully modified data for region: grinnell-3-sw
# Type  Year     Month       Stations    prec   tmax   tmin
# 0     2015   Month_1  grinnell-3-sw   19.56  -1.27 -11.83
# 1     2015  Month_10  grinnell-3-sw   67.56  17.37   4.52
# 2     2015  Month_11  grinnell-3-sw   84.84  10.83  -0.52
# 3     2015  Month_12  grinnell-3-sw  149.10   5.07  -2.28
# 4     2015   Month_2  grinnell-3-sw   31.76  -5.02 -17.38
# Successfully modified data for region: grundy-center
# Type  Year     Month       Stations    prec   tmax   tmin
# 0     2015   Month_1  grundy-center    8.39  -2.04 -11.54
# 1     2015  Month_10  grundy-center   46.74  17.44   4.81
# 2     2015  Month_11  grundy-center   70.87   9.81   0.31
# 3     2015  Month_12  grundy-center  208.30   4.09  -2.72
# 4     2015   Month_2  grundy-center   39.12  -6.13 -17.24
# Successfully modified data for region: iowa average
# Type  Year     Month      Stations    prec   tmax   tmin
# 0     2015   Month_1  iowa average   12.45  -0.05 -11.61
# 1     2015  Month_10  iowa average   43.43  18.77   4.94
# 2     2015  Month_11  iowa average  102.11  11.48  -0.22
# 3     2015  Month_12  iowa average  123.44   5.02  -3.54
# 4     2015   Month_2  iowa average   30.99  -3.67 -16.13
# Successfully modified data for region: marshalltown municipal ap
# Type  Year     Month                   Stations    prec   tmax   tmin
# 0     2015   Month_1  marshalltown municipal ap   21.87  -0.45 -10.73
# 1     2015  Month_10  marshalltown municipal ap   44.46  17.54   5.46
# 2     2015  Month_11  marshalltown municipal ap   72.14  10.74   0.15
# 3     2015  Month_12  marshalltown municipal ap  114.57   4.68  -2.47
# 4     2015   Month_2  marshalltown municipal ap    3.58  -5.66 -16.69
# Successfully modified data for region: toledo
# Type  Year     Month Stations    prec   tmax   tmin
# 0     2015   Month_1   toledo   17.29  -1.68 -11.45
# 1     2015  Month_10   toledo   59.44  17.80   4.78
# 2     2015  Month_11   toledo   68.58  10.09   0.41
# 3     2015  Month_12   toledo  116.86   4.59  -2.42
# 4     2015   Month_2   toledo   27.45  -5.81 -17.00
# Successfully modified data for region: anamosa3ssw
# Type  Year     Month     Stations    prec   tmax   tmin
# 0     2015   Month_1  anamosa3ssw   14.22  -1.72 -10.88
# 1     2015  Month_10  anamosa3ssw   81.54  17.50   4.93
# 2     2015  Month_11  anamosa3ssw  114.30  10.78   0.04
# 3     2015  Month_12  anamosa3ssw  115.34   5.90  -1.88
# 4     2015   Month_2  anamosa3ssw   41.16  -5.43 -16.36
# Successfully modified data for region: cascade
# Type  Year     Month Stations    prec   tmax   tmin
# 0     2015   Month_1  cascade   14.99  -2.53 -12.28
# 1     2015  Month_10  cascade   78.74  17.72   4.72
# 2     2015  Month_11  cascade  120.40  10.82  -0.17
# 3     2015  Month_12  cascade  114.32   5.81  -1.38
# 4     2015   Month_2  cascade   36.58  -5.97 -17.78
# Successfully modified data for region: cedarrapids1
# Type  Year     Month      Stations    prec   tmax   tmin
# 0     2015   Month_1  cedarrapids1   14.23  -0.31 -10.24
# 1     2015  Month_10  cedarrapids1   84.08  18.33   6.72
# 2     2015  Month_11  cedarrapids1  102.11  11.57   1.19
# 3     2015  Month_12  cedarrapids1  114.05   5.65  -1.04
# 4     2015   Month_2  cedarrapids1   31.75  -4.23 -15.10
# Successfully modified data for region: cedarrapidsarea
# Type  Year     Month         Stations    prec   tmax   tmin
# 0     2015   Month_1  cedarrapidsarea   21.61  -0.72 -10.95
# 1     2015  Month_10  cedarrapidsarea   88.40  17.58   5.79
# 2     2015  Month_11  cedarrapidsarea  113.80  10.90   0.65
# 3     2015  Month_12  cedarrapidsarea  103.39   5.47  -1.43
# 4     2015   Month_2  cedarrapidsarea   12.21  -5.62 -16.61
# Successfully modified data for region: clinton1
# Type  Year     Month  Stations    prec   tmax   tmin
# 0     2015   Month_1  clinton1   28.20  -0.84  -9.46
# 1     2015  Month_10  clinton1   71.89  18.19   7.54
# 2     2015  Month_11  clinton1  171.20  11.99   1.65
# 3     2015  Month_12  clinton1  119.64   6.63  -0.54
# 4     2015   Month_2  clinton1   37.86  -4.37 -14.72
# Successfully modified data for region: dubuquearea
# Type  Year     Month     Stations    prec   tmax   tmin
# 0     2015   Month_1  dubuquearea   23.63  -2.42 -11.51
# 1     2015  Month_10  dubuquearea   69.86  16.77   5.48
# 2     2015  Month_11  dubuquearea  136.65   9.79  -0.11
# 3     2015  Month_12  dubuquearea  106.44   4.46  -2.03
# 4     2015   Month_2  dubuquearea   34.56  -6.61 -17.32
# Successfully modified data for region: iowaeastcentral
# Type  Year     Month         Stations    prec   tmax   tmin
# 0     2015   Month_1  iowaeastcentral   18.03  -0.72 -11.37
# 1     2015  Month_10  iowaeastcentral   71.88  18.66   5.16
# 2     2015  Month_11  iowaeastcentral  121.67  11.74  -0.02
# 3     2015  Month_12  iowaeastcentral  124.21   6.63  -1.79
# 4     2015   Month_2  iowaeastcentral   37.08  -4.28 -16.67
# Successfully modified data for region: lowden
# Type  Year     Month Stations    prec   tmax   tmin
# 0     2015   Month_1   lowden   32.27  -1.16 -11.33
# 1     2015  Month_10   lowden   78.24  18.48   5.65
# 2     2015  Month_11   lowden  140.72  11.59   0.28
# 3     2015  Month_12   lowden  106.18   6.26  -1.13
# 4     2015   Month_2   lowden   30.00  -5.30 -17.60
# Successfully modified data for region: manchester2
# Type  Year     Month     Stations    prec   tmax   tmin
# 0     2015   Month_1  manchester2   17.02  -2.85 -12.97
# 1     2015  Month_10  manchester2   63.25  17.13   3.91
# 2     2015  Month_11  manchester2  105.41   9.94  -0.81
# 3     2015  Month_12  manchester2  127.03   4.91  -2.35
# 4     2015   Month_2  manchester2   36.34  -6.61 -18.33
# Successfully modified data for region: maquioketa2w
# Type  Year     Month      Stations    prec   tmax   tmin
# 0     2015   Month_1  maquioketa2w   14.74  -2.74 -11.90
# 1     2015  Month_10  maquioketa2w   61.22  17.38   4.89
# 2     2015  Month_11  maquioketa2w  111.51  10.33  -0.94
# 3     2015  Month_12  maquioketa2w  106.19   5.50  -1.88
# 4     2015   Month_2  maquioketa2w   41.16  -6.31 -17.86

# %%
# Try to merge data into a single file starting from regional meteological data.

# Initialize an empty list to store DataFrames
df_list = []

# Loop through each region and read the corresponding CSV file
for region in stations:
    df = pd.read_csv(f"{region}_modified.csv")
    df['Stations'] = region  # Add a 'Region' column
    df_list.append(df)

# Concatenate all DataFrames into a single DataFrame
merged_df = pd.concat(df_list)

# Save the merged DataFrame to a new CSV file
merged_df.to_csv("merged_regions.csv", index=False)

# %%
# We found out that the merged_regions.csv does not have region column so here we will add region column using for loop. 
# Region column is necessary for us to carry out inner-join task with the explanatory dataset (Corn.csv) at the later stage.

# Load the merged file
df = pd.read_csv("merged_regions.csv")

# List of stations
stations = ["burlington", "columbus junct 2 ssw", "fairfield", "iowa - southeast climate division", "keosauqua", "burlingtonairport", "donnellson", "fortmadison", "keokuk", "mount-pleasant", 
           "allerton", "centerville", "chariton", "des moines area", "iowa - south central climate division", "iowa drought region 5 - southeast", "newton", "osceola-3-wsw", "oskaloosa", "rathbun dam",
           "atlantic-1-ne", "clarinda", "corning", "creston", "greenfield", "iowa - southwest climate division", "iowa drought region 4 - southwest", "oakland-2-e", "shenandoah-1-ne", "winterset",
           "iowadroughtregion1", "iowanorthwestclimate", "lemars", "primghar", "rockrapids", "sibley5", "siouxcenter", "spencer", "siouxrapids", "spencerarea",
           "algona", "estherville4e", "esthervillemunicipal", "fortdodge", "iowadroughtregion2", "jefferson", "pocahontas", "saccity", "emmetsburg", "webstercity",
           "audubon", "battle creek 3ne", "carroll-2-ssw", "denison", "ida grove area", "iowa - west central climate division", "little sioux 2nw", "mapleton no. 2", "sac-city", "sioux city area",
           "elkader6ssw", "fayette", "iowadroughtregion3", "iowanortheastclimatedivision", "newhampton", "oelwein1e", "oelweinarea", "postville", "stanley", "waukon",
           "ames 5 se", "ames area", "ames municipal ap", "ames-8-wsw", "boone", "grinnell-3-sw", "grundy-center", "iowa average", "marshalltown municipal ap", "toledo",
           "anamosa3ssw", "cascade", "cedarrapids1", "cedarrapidsarea", "clinton1", "dubuquearea", "iowaeastcentral", "lowden", "manchester2", "maquioketa2w"]

# Initialize regions
regions = ["southeast", "southcentral", "southwest", "northwest", "northcentral", "westcentral", "northeast", "central", "eastcentral"]

# Create a dictionary to map stations to regions
station_to_region = {}
for i, region in enumerate(regions):
    for station in stations[i*10:(i+1)*10]:
        station_to_region[station] = region

# Add a new column 'Region' to the DataFrame
df['Region'] = df['Stations'].map(station_to_region)

# Save the modified DataFrame to a new CSV file
df.to_csv("merged_regions_modified.csv", index=False)

print("The new column 'Region' has been added and the modified DataFrame has been saved to 'merged_regions_modified.csv'.")
# Out:
# The new column 'Region' has been added and the modified DataFrame has been saved to 'merged_regions_modified.csv'.

# %%
# Checking whether the code executed according to our expectation
df['Region'].value_counts()
# Out:
# Region
# southeast       1200
# southcentral    1200
# southwest       1200
# northwest       1200
# northcentral    1200
# westcentral     1200
# northeast       1200
# central         1200
# eastcentral     1200
# Name: count, dtype: int64

# %% [markdown]
# ### Merging Corn + Merged_Meteorological Data (90 Stations)
# Now, it is better to delete all meteorological data 90 stations + 90 Modified files and only leave "Merged_regions_modified.csv"
#
# And please add "Corn.csv" file on the platform

# %%
## Here we will merge merged_region_modified file with the corn data (Explanatory variable).
## Please unzip corn folder and load the file directly next to this code like you did for meteorological data
## Now we will merge the corn data with the merged regions data
## We will first load the corn data, aggregate it, and then merge it with the merged regions data

# Load the CSV files
corn_df = pd.read_csv('Corn.csv')

# Keep only Year, Ag District, and Value columns in the Corn data and create a copy to avoid warnings
corn_df_reduced = corn_df[['Year', 'Ag District', 'Value']].copy()
 
# Convert the 'Value' column to numeric, handling commas
corn_df_reduced['Value'] = corn_df_reduced['Value'].replace(',', '', regex=True).astype(float)

# Aggregate by Year and Ag District, summing the values
corn_df_aggregated = corn_df_reduced.groupby(['Year', 'Ag District']).sum().reset_index()

# Renaming 'Ag District' to 'Region' in the first dataset to match the column name in merged_regions_df
corn_df_aggregated.rename(columns={'Ag District': 'Region'}, inplace=True)

corn_df_aggregated
# Out:
#     Year         Region        Value
# 0   2015        CENTRAL  369962000.0
# 1   2015   EAST CENTRAL  257582000.0
# 2   2015  NORTH CENTRAL  364763000.0
# 3   2015      NORTHEAST  311052000.0
# 4   2015      NORTHWEST  382845000.0
# ..   ...            ...          ...
# 67  2022      NORTHWEST  337170000.0
# 68  2022  SOUTH CENTRAL   74502000.0
# 69  2022      SOUTHEAST  152549000.0
# 70  2022      SOUTHWEST  174484000.0
# 71  2022   WEST CENTRAL  372069000.0
#
# [72 rows x 3 columns]

# %%
# Let's check how we are going to merge these two csv using regions
# First check how regions are spelled in each dataset

# Merged_regions_df has a column and we need to see what unique values are in that column
merged_regions_df['Region'].unique()
# Out:
# array(['southeast', 'southcentral', 'southwest', 'northwest',
#        'northcentral', 'westcentral', 'northeast', 'central',
#        'eastcentral'], dtype=object)

# %%
# Same for corn_df_aggregated 
corn_df_aggregated['Region'].unique()
# Out:
# array(['CENTRAL', 'EAST CENTRAL', 'NORTH CENTRAL', 'NORTHEAST',
#        'NORTHWEST', 'SOUTH CENTRAL', 'SOUTHEAST', 'SOUTHWEST',
#        'WEST CENTRAL'], dtype=object)

# %%
# Create a mapping dictionary to standardize the values in the 'Region' column
# This is a manual process, but it is necessary to ensure that the values in the 'Region' column are consistent across both datasets
standardization_map = { 'CENTRAL': 'central', 'EAST CENTRAL': 'eastcentral', 'NORTH CENTRAL': 'northcentral', 'NORTHEAST': 'northeast', 'NORTHWEST': 'northwest', 'SOUTH CENTRAL': 'southcentral', 'SOUTHEAST': 'southeast', 'SOUTHWEST': 'southwest', 'WEST CENTRAL': 'westcentral' }

# Standardize region names in the DataFrame to lowercase and remove spaces 
corn_df_aggregated['Region'] = corn_df_aggregated['Region'].str.lower().str.replace(' ', '') 
# Perform replacement using the standardized map 
corn_df_aggregated['Region'] = corn_df_aggregated['Region'].replace(standardization_map)


corn_df_aggregated['Region'].unique()
merged_regions_df['Region'].unique()


# Merge the dataframes on 'Year' and 'Region'
merged_df = pd.merge(corn_df_aggregated, merged_regions_df, on=['Year', 'Region'], how='inner')

# Save it to a new csv file
merged_df.to_csv('corn_merged.csv', index=False)

# We have successfully merged two dataset into one under the file name "corn_merged.csv"

# %%
# For a better analysis, we are changing Month to numeric values

# Load the corn_merged.csv file
df = pd.read_csv("corn_merged.csv")

# Convert the 'Month' column values to numeric
df['Month'] = df['Month'].str.replace('Month_', '').astype(int)

# Save the modified DataFrame to a new CSV file
df.to_csv("corn_merged_modified.csv", index=False)

print("The 'Month' column values have been converted to numeric and the modified DataFrame has been saved to 'corn_merged_modified.csv'.")
# Out:
# The 'Month' column values have been converted to numeric and the modified DataFrame has been saved to 'corn_merged_modified.csv'.

# %% [markdown]
# ### Merging Corn_Merged with Biodiesel Data
#
# And please add "US_Bioenergy_Statistics.csv" file on the platform

# %%
# Load the dataset without headers
df = pd.read_csv('US_Bioenergy_Statistics.csv', header=None)
 
# Because it does not have a column name, let's add column names
df.columns = ['Year', 'Month', 'Biodiesel', 'Diesel', 'Price Difference']
 
# Create a dictionary to map month names to numeric values
month_map = {
    'Jan': 1, 'Feb': 2, 'Mar': 3, 'Apr': 4, 'May': 5, 'Jun': 6,
    'Jul': 7, 'Aug': 8, 'Sep': 9, 'Oct': 10, 'Nov': 11, 'Dec': 12
}
 
# Replace month names with numeric values
df['Month'] = df['Month'].map(month_map)
 
# Save the modified DataFrame to a new CSV file with metadata
df.to_csv('US_Bioenergy_Statistics_with_metadata.csv', index=False)
 
# Display the first few rows of the modified DataFrame to verify
print(df.head())
# Out:
#    Year  Month  Biodiesel  Diesel  Price Difference
# 0  2014      1       3.28    3.89             -0.61
# 1  2014      2       3.37    3.98             -0.61
# 2  2014      3       3.70    4.00             -0.30
# 3  2014      4       3.76    3.96             -0.20
# 4  2014      5       3.75    3.94             -0.19

# %%
# Load the datasets
corn_data = pd.read_csv('corn_merged_modified.csv')
bioenergy_data = pd.read_csv('US_Bioenergy_Statistics_with_metadata.csv')
 
# Merge the datasets on the 'Year' column
merged_data = pd.merge(corn_data, bioenergy_data, on='Year')
 
# Display the first few rows of the merged dataset
print("First few rows of the merged dataset:")
print(merged_data.head())
 
# Save the merged dataset to a new CSV file
merged_data.to_csv('Corn&Biodieselmerged_dataset.csv', index=False)

merged_data
# Out:
# First few rows of the merged dataset:
#    Year   Region        Value  Month_x   Stations   prec  tmax   tmin  \
# 0  2015  central  369962000.0        1  ames 5 se  17.04 -0.79 -11.54
# 1  2015  central  369962000.0        1  ames 5 se  17.04 -0.79 -11.54
# 2  2015  central  369962000.0        1  ames 5 se  17.04 -0.79 -11.54
# 3  2015  central  369962000.0        1  ames 5 se  17.04 -0.79 -11.54
# 4  2015  central  369962000.0        1  ames 5 se  17.04 -0.79 -11.54
#
#    Month_y  Biodiesel  Diesel  Price Difference
# 0        1       2.85    3.00             -0.15
# 1        2       2.92    2.86              0.06
# 2        3       2.89    2.90             -0.01
# 3        4       2.92    2.78              0.13
# 4        5       3.11    2.89              0.22
#         Year       Region        Value  Month_x         Stations   prec  \
# 0       2015      central  369962000.0        1        ames 5 se  17.04
# 1       2015      central  369962000.0        1        ames 5 se  17.04
# 2       2015      central  369962000.0        1        ames 5 se  17.04
# 3       2015      central  369962000.0        1        ames 5 se  17.04
# 4       2015      central  369962000.0        1        ames 5 se  17.04
# ...      ...          ...          ...      ...              ...    ...
# 103675  2022  westcentral  372069000.0        9  sioux city area  19.31
# 103676  2022  westcentral  372069000.0        9  sioux city area  19.31
# 103677  2022  westcentral  372069000.0        9  sioux city area  19.31
# 103678  2022  westcentral  372069000.0        9  sioux city area  19.31
# 103679  2022  westcentral  372069000.0        9  sioux city area  19.31
#
#          tmax   tmin  Month_y  Biodiesel  Diesel  Price Difference
# 0       -0.79 -11.54        1       2.85    3.00             -0.15
# 1       -0.79 -11.54        2       2.92    2.86              0.06
# 2       -0.79 -11.54        3       2.89    2.90             -0.01
# 3       -0.79 -11.54        4       2.92    2.78              0.13
# 4       -0.79 -11.54        5       3.11    2.89              0.22
# ...       ...    ...      ...        ...     ...               ...
# 103675  27.76  10.89        8       6.71    5.01              1.70
# 103676  27.76  10.89        9       6.79    4.99              1.80
# 103677  27.76  10.89       10       6.81    5.21              1.60
# 103678  27.76  10.89       11       6.72    5.26              1.47
# 103679  27.76  10.89       12       5.87    4.71              1.15
#
# [103680 rows x 12 columns]

# %%
# Load the modified biodiesel dataset
df1 = pd.read_csv('US_Bioenergy_Statistics_with_metadata.csv')
 
# Load the corn_merged_modified dataset
df2 = pd.read_csv('corn_merged_modified.csv')
 
# Merge the datasets on 'Year' and 'Month'
merged_df = pd.merge(df1, df2, on=['Year', 'Month'])
 
# Display the first few rows of the merged DataFrame to verify
print(merged_df.head())
 
 
merged_df.to_csv('finished.csv', index=False)
# Out:
#    Year  Month  Biodiesel  Diesel  Price Difference   Region        Value  \
# 0  2015      1       2.85     3.0             -0.15  central  369962000.0
# 1  2015      1       2.85     3.0             -0.15  central  369962000.0
# 2  2015      1       2.85     3.0             -0.15  central  369962000.0
# 3  2015      1       2.85     3.0             -0.15  central  369962000.0
# 4  2015      1       2.85     3.0             -0.15  central  369962000.0
#
#             Stations   prec  tmax   tmin
# 0          ames 5 se  17.04 -0.79 -11.54
# 1          ames area  17.20 -0.79 -11.54
# 2  ames municipal ap  28.97  0.29 -10.68
# 3         ames-8-wsw   4.83  1.19  -9.76
# 4              boone  16.27 -0.39 -11.72
